# %% [markdown]
# ## <font color="red">Student name:</font>

# %%
#Start all notebooks with these lines.  They set a lot of variables to values we want to use,
#and read in some important packages of routines, too.
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Introductory notes: A few python tips, and some sample code

# %% [markdown]
# A few python tips:
#
# To run a cell in a jupyter notebook, hold down the Shift key while you press Return or Enter.  Or, use the play arrow.
#
# Save your notebook often.  Go to "File:Save and checkpoint" or click the floppy drive icon (left-most icon).
#
# Use #'s at the beginning of a line to make them comments.
#
# Google is your friend.  Your questions about python can probaby be answered with a few minutes of googling.
#
# Python plots are made with something called matplotlib, so for questions about plots, add "matplotlib" to your search string in google.

# %% [markdown]
# Here is some simple example code to make a plot.  Four your own plots, you can copy and place different elements of this code and modify as needed.

# %%
planet_names=["Mercury", "Venus", "Earth"]    #Fill out with other planets
planet_a=np.array([1,2,3])     #Replace/add the planet semi-major axes here
planet_mass=np.array([100,200,300])   #Replace/add the planet masses here

# %%
#All plots should have these two lines
#First, we create a "Figure" object
fig=plt.figure(1,figsize=(18,5))  #Numbers in parentheses determine the dimensions of the plot
#Next, we create an "axis" object.  I'll call this "ax1" (that's a number 1, not the letter l)
#If I wanted more than one plot, I might call the next ax2, and the next ax3, etc.
ax1=fig.add_subplot(111)     #11 Means make a grid 1 plot box wide by 1 box tall.
                             #The final 1 means let ax1 be the first plot box.

#Plot desired x and y points.  'ro' tells python to make the points red (r) circles (o).
ax1.plot(planet_a, planet_mass, 'ro')

#Now use a loop to label each point with the planet name
for i, (x, y) in enumerate(zip(planet_a, planet_mass)):
    ax1.text(x,y,planet_names[i],fontsize=14)
#Make sure to check that the font is legible on your plot

#When plotting functions, you need to create a number of x and y values and then plot them.
#One convenient way to create a lot of x values is to use numpy's "arange" "linspace" or
#"logspace" functions

#Plot the function y=100x
x=np.arange(0,1000,1)  #Make x a long list of numbers from 0 to 1000, counting by 1
y=100*x                #Let y = 100 times x
ax1.plot(x,y)       #Plot y vs. x.  By default, python will plot a solid line.

ax1.set_yscale('linear')
ax1.set_xscale('linear')
#Change these to 'log' to make a log plot.  Caution!  You do not want to have a 0 in a log plot.
#(Because, what is the log of 0?)

#Label your axes
ax1.set_xlabel('Planet index',fontsize=18)
ax1.set_ylabel('Planet index x 100',fontsize=18)

#Set x and y plot limits
ax1.set_xlim(1,4)   #Set limits for x axis to make the plot look better
ax1.set_ylim(90,400)  #Set limits for y axis to make the plot look better

#Use these lines to increase the font size of the x and y axis labels
for tick in ax1.xaxis.get_major_ticks():   #Change x axis label sizes
    tick.label1.set_fontsize(17)
    tick.label1.set_fontweight('medium')
for tick in ax1.yaxis.get_major_ticks():   #Change y axis label sizes
    tick.label1.set_fontsize(17)
    tick.label1.set_fontweight('medium')
#Check to make sure the font is legible on your final plot

# %% [markdown]
# To write some text in this area, I've switched the drop-down menu above from "Code" to "Markdown".  Now I can write all the notes I'd like about this plot.  I can also add math, using syntax similar to that used by LaTeX.  Math code needs to be surrounded by dollar signs.  For example, in this plot above, I am plotting the function $y=100 x$.  For homework, you will plot $y=x$ and $y=x^2$.  Double click on this area of the notebook to see the Markdown code.

# %% [markdown]
# ## Question 1: Solar system demographics and introduction to jupyter notebooks

# %% [markdown]
# ### 1(a) Plot the masses of the planets vs. distance from the sun.  (Note, "mass vs. distance" implies that mass is on the y axis and distance is on the x axis)

# %% [markdown]
# <font color="red">*Comments from instructor:*</font>

# %% [markdown]
# ### 1(b) Do you see evidence for 3 categories of planets (corresponding to terrestrial, ice giants, and gas giants)?  Explain your answer.

# %% [markdown]
# <font color="red">*Comments from instructor:*</font>

# %% [markdown]
# ### 1(c) Re-plot the masses of the planets, but this time use a log y axis.

# %% [markdown]
# <font color="red">*Comments from instructor:*</font>

# %% [markdown]
# ### 1(d) Do you see evidence for 3 categories of planets?  Explain your answer.

# %% [markdown]
# <font color="red">*Comments from instructor:*</font>

# %% [markdown]
# ### 1(e): Plot the densities of the planets vs. distance from the sun.  Try both a linear and log axis for the x-axis and see which one looks better.

# %% [markdown]
# <font color="red">*Comments from instructor:*</font>

# %% [markdown]
# ### 1(f): Describe any trends that you see in the plot you just created.  What are possible explanations for these trends?

# %% [markdown]
# <font color="red">*Comments from instructor:*</font>

# %% [markdown]
# ## Question 2: Dynamics

# %% [markdown]
# ### 2(a): Plot the period of each planet's orbit on the y-axis vs. semi-major axis, a, on the x-axis.  On top of these points, plot curves of the form $y=Ax$ and $y=Bx^2$, where $A$ and $B$ are adjusted so that the curves intersect the period and semi-major axis of Mercury.

# %% [markdown]
# <font color="red">*Comments from instructor:*</font>

# %% [markdown]
# ### 2(b): How do the periods increase with semi-major axis compared to these 2 curves?

# %% [markdown]
# <font color="red">*Comments from instructor:*</font>

# %% [markdown]
# ### 2(c): Assuming all planets are undergoing *uniform circular motion*, use Newton's 2nd law, Newton's law of gravitation, and your knowledge of uniform circular motion to derive a relationship between orbital period and radius of an orbit.   Show that this is equivalent to Kepler's 3rd law, which says that $P^2 \propto a^3$ where $P$ is the period of an orbit, and $a$ is its semi-major axis (equivalent to radius for a circular orbit).

# %% [markdown]
# <font color="red">*Comments from instructor:*</font>

# %% [markdown]
# ### 2(d): Add a curve demonstrating Kepler’s 3rd law to your plot.

# %% [markdown]
# <font color="red">*Comments from instructor:*</font>

# %% [markdown]
# ### 2(e): Does Kepler’s 3rd law apply to all stars or only the sun? In what way(s) (if at all), would the period of orbits around a more massive star be different? Explain your answers.

# %% [markdown]
# <font color="red">*Comments from instructor:*</font>

# %% [markdown]
# ## 3: Applying your knowledge: Planet 9

# %% [markdown]
# There is new evidence for an approximately 10-Earth-mass planet (nicknamed "Planet 9") orbiting the sun at a=700 AU.  (Google "Planet 9" to find out more).

# %% [markdown]
# ### 3(a): What would be the length of a year on this planet, in units of Earth years? (Yes, you can probably find this answer online. Please do the calculation yourself!)

# %% [markdown]
# <font color="red">*Comments from instructor:*</font>

# %% [markdown]
# Given what you know about the solar system and Planet 9 (mass and semi-major axis), speculate about the following questions:

# %% [markdown]
# ### 3(b): If we sent a probe to Planet 9, what would it look like?  What type of planet would it be?  Explain your answer.

# %% [markdown]
# <font color="red">*Comments from instructor:*</font>

# %% [markdown]
# ### 3(c): Do you think Planet 9 formed at 700 AU (this is called “in-situ” formation) or, alternatively, was it formed somewhere else and transported to its current location? Why? (We will talk about these issues in detail later in the semester. For now, just try to think creatively about this question).

# %% [markdown]
# <font color="red">*Comments from instructor:*</font>

# %% [markdown]
# ### 3(d): Propose a test to determine where Planet 9 formed.  Is your test an observational test, a modeling-based test, or something else?  Clearly describe the predictions of your test for the in-situ formation scenario vs. the transport scenario.

# %% [markdown]
# <font color="red">*Comments from instructor:*</font>

# %% [markdown]
# ## Question 4: Creative thinking

# %% [markdown]
# ### 4(a): Consider some aspect(s) of the solar system of your choice and make a related plot using python.

# %% [markdown]
# <font color="red">*Comments from instructor:*</font>

# %% [markdown]
# ### 4(b): What did you learn from the plot you made in 4(a)?

# %% [markdown]
# <font color="red">*Comments from instructor:*</font>

# %% [markdown]
# ## <font color="red"> Grade </font>

# %% [markdown]
# <font color="red"> Calculations: </font>

# %%
calculations_grade=0

# %% [markdown]
# <font color="red"> Concepts: </font>

# %%
concepts_grade=0

# %% [markdown]
# <font color="red"> Communication: </font>

# %%
communication_grade=0

# %% [markdown]
# <font color="red"> Total grade: </font>

# %%
print(calculations_grade+concepts_grade+communication_grade)
# Out:
# 0
